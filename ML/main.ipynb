# %% [markdown]
# # Notebook for a prediction ML model
# - This model use a `melb_data.csv` like a dataset
# - The data set the melbourne houses price

# %%
import pandas as pd

melb_df = pd.read_csv('melb_data.csv')
melb_df
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
melb_df.describe()
# Out:
#          Unnamed: 0         Rooms         Price      Distance      Postcode  \
# count  18396.000000  18396.000000  1.839600e+04  18395.000000  18395.000000
# mean   11826.787073      2.935040  1.056697e+06     10.389986   3107.140147
# std     6800.710448      0.958202  6.419217e+05      6.009050     95.000995
# min        1.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     5936.750000      2.000000  6.330000e+05      6.300000   3046.000000
# 50%    11820.500000      3.000000  8.800000e+05      9.700000   3085.000000
# 75%    17734.250000      3.000000  1.302000e+06     13.300000   3149.000000
# max    23546.000000     12.000000  9.000000e+06     48.100000   3978.000000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  14927.000000  14925.000000  14820.000000   13603.000000   7762.000000
# mean       2.913043      1.538492      1.615520     558.116371    151.220219
# ...

# %% [markdown]
# ## Limpieza de datos

# %%
melb_df = melb_df.dropna(axis = 0)
melb_df
# Out:
#        Unnamed: 0        Suburb          Address  Rooms Type      Price  \
# 1               2    Abbotsford  25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford     5 Charles St      3    h  1465000.0
# 4               6    Abbotsford      55a Park St      4    h  1600000.0
# 6              11    Abbotsford     124 Yarra St      3    h  1876000.0
# 7              14    Abbotsford    98 Charles St      2    h  1636000.0
# ...           ...           ...              ...    ...  ...        ...
# 15388       19732    Whittlesea    30 Sherwin St      3    h   601000.0
# 15389       19733  Williamstown      75 Cecil St      3    h  1050000.0
# 15390       19734  Williamstown    2/29 Dover Rd      1    u   385000.0
# 15392       19736       Windsor  201/152 Peel St      2    u   560000.0
# 15395       19739    Yarraville  54 Pentland Pde      6    h  2450000.0
#
#       Method        SellerG        Date  Distance  ...  Bathroom  Car  \
# ...

# %% [markdown]
# ## Machine learning

# %%
y = melb_df['Price']
x = melb_df[['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']]

# %% [markdown]
# ### Arbol de decisiones

# %%
from sklearn.tree import DecisionTreeRegressor
from datetime import datetime

melbourne_model = DecisionTreeRegressor()
melbourne_model.fit(x, y)
fecha_entrenamiento = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# %% [markdown]
# ### Regresion linel

# %%
from sklearn.linear_model import LinearRegression


melbourne_lineal = LinearRegression(n_jobs=-1)
melbourne_lineal.fit(x, y)

print("Predicciones para las 5 primeras casas (Regresión Lineal):")
print(x.head())

print("El precio real es:")
print(y.head())

print("Las predicciones son:")
print(melbourne_lineal.predict(x.head()))
# Out:
# Predicciones para las 5 primeras casas (Regresión Lineal):
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 4      4       1.0     120.0   -37.8072    144.9941
# 6      3       2.0     245.0   -37.8024    144.9993
# 7      2       1.0     256.0   -37.8060    144.9954
# El precio real es:
# 1    1035000.0
# 2    1465000.0
# 4    1600000.0
# 6    1876000.0
# 7    1636000.0
# Name: Price, dtype: float64
# Las predicciones son:
# [ 686860.76637915 1186304.89232916 1202609.4350245  1180775.43309477
#   686960.13022307]

# %%
print("Predicciones para las 5 primereas casas: ")
print(x.head(100))
print("El precio real es: ")
print(y.head(100))
print("Las predicciones son")
print(melbourne_model.predict(x.head(100)))
# Out:
# Predicciones para las 5 primereas casas:
#      Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1        2       1.0     156.0   -37.8079    144.9934
# 2        3       2.0     134.0   -37.8093    144.9944
# 4        4       1.0     120.0   -37.8072    144.9941
# 6        3       2.0     245.0   -37.8024    144.9993
# 7        2       1.0     256.0   -37.8060    144.9954
# ..     ...       ...       ...        ...         ...
# 209      2       1.0       0.0   -37.8678    144.8384
# 211      4       1.0     745.0   -37.8658    144.8155
# 215      3       2.0      69.0   -37.8680    144.8286
# 219      2       1.0     137.0   -37.8655    144.8299
# 221      3       1.0     606.0   -37.8608    144.8124
#
# [100 rows x 5 columns]
# El precio real es:
# 1      1035000.0
# 2      1465000.0
# 4      1600000.0
# 6      1876000.0
# 7      1636000.0
#          ...
# 209     391000.0
# 211     845000.0
# 215     730000.0
# 219     447000.0
# 221     678000.0
# ...

# %% [markdown]
# ## MAE
# Ver las metricas de errores absolutos

# %%
from sklearn.metrics import mean_absolute_error

predicted_home_prices = melbourne_model.predict(x)
mean_absolute_error(y, predicted_home_prices)
# Out:
# 1115.7467183128902

# %% [markdown]
# ## Validacion

# %%
from sklearn.model_selection import train_test_split

train_X, val_X, train_Y, val_y = train_test_split(x, y)

melbourne_model = DecisionTreeRegressor()
melbourne_model.fit(train_X, train_Y)

val_predictions = melbourne_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 241325.4932214332

# %%
from sklearn.ensemble import RandomForestRegressor

forest_model = RandomForestRegressor()
forest_model.fit(train_X, train_Y)
melb_preds = forest_model.predict(val_X)
print(mean_absolute_error(val_y, melb_preds))
# Out:
# 179993.45793138433

# %% [markdown]
# ## Graficos

# %% [markdown]
# ### Por regresion de arbol

# %%
import matplotlib.pyplot as plt
import numpy as np

# Tomar las primeras 100 casas
x_100 = x.head(100)
y_100 = y.head(100)

# Predicciones
predictions_100 = melbourne_model.predict(x_100)

# Índices de las casas
houses = np.arange(1, 101)

# Crear gráfica
plt.figure(figsize=(15, 6))

# Precios reales
plt.plot(houses, y_100.values, label='Precio real')

# Predicciones
plt.plot(houses, predictions_100, label='Predicción')

# Títulos y etiquetas
plt.title("Precios reales vs Predicciones (100 primeras casas)")
plt.xlabel("Número de casa")
plt.ylabel("Precio")

# Leyenda
plt.legend()

# Cuadrícula
plt.grid(True)

# Mostrar gráfica
plt.show()

# %% [markdown]
# ### Regresion de línea

# %%
import matplotlib.pyplot as plt
import numpy as np

# Tomar las primeras 100 casas
x_100 = x.head(100)
y_100 = y.head(100)

# Predicciones
predictions_100 = melbourne_lineal.predict(x_100)

# Índices de las casas
houses = np.arange(1, 101)

# Crear gráfica
plt.figure(figsize=(15, 6))

# Precios reales
plt.plot(houses, y_100.values, label='Precio real')

# Predicciones
plt.plot(houses, predictions_100, label='Predicción')

# Títulos y etiquetas
plt.title("Precios reales vs Predicciones (100 primeras casas)")
plt.xlabel("Número de casa")
plt.ylabel("Precio")

# Leyenda
plt.legend()

# Cuadrícula
plt.grid(True)

# Mostrar gráfica
plt.show()

# %% [markdown]
# # Manejo de SQL y guardado de la data de errores y mejora de entrenamientos

# %% [markdown]
# ### Creacion de la base de datos

# %%
import sqlite3 as sql

con = sql.connect("newmodel.db")
cur = con.cursor()

# Creacion de la tabla principal
cur.execute('''CREATE TABLE IF NOT EXISTS model_error (
            id INTEGER PRIMARY KEY,
            entrenamiento INT,
            error INT
            )
''')

con.commit()

# %% [markdown]
# **Agregar los datos a la base de datos progresivamente**

# %%
from datetime import datetime
import sqlite3 as sql

# Fecha actual
fecha_entrenamiento = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
err = mean_absolute_error(val_y, melb_preds)

# Usar context manager para asegurar que la conexión se cierre
with sql.connect("newmodel.db", timeout=30.0) as con:
    cur = con.cursor()
    cur.execute('''
    INSERT INTO model_error (entrenamiento, error)
    VALUES (?, ?)
    ''', (fecha_entrenamiento, err))
    con.commit()

# %% [markdown]
# **Sacar los datos de la tabla de modelia**

# %%
df_sql = pd.read_sql_query(
    "SELECT * FROM model_error",
    con
)

df_sql["entrenamiento"] = pd.to_datetime(df_sql["entrenamiento"])

# Ordenar por fecha (importante)
df_sql = df_sql.sort_values("entrenamiento")
print(df_sql)
# Out:
#    id       entrenamiento          error
# 0   1 2026-05-08 23:40:28  194727.405623
# 1   2 2026-05-08 23:40:38  197259.721313
# 2   3 2026-05-08 23:40:42  198792.333606
# 3   4 2026-05-08 23:40:46  190678.624543
# 4   5 2026-05-08 23:40:50  179993.457931

# %%
con.commit()
cur.close()
con.close()

# %% [markdown]
# ## Graficos de errores y avance

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,5))
plt.plot(df_sql["entrenamiento"], df_sql["error"])

plt.title("Evolución del error del modelo")
plt.xlabel("Fecha de entrenamiento")
plt.ylabel("Mean Absolute Error (MAE)")
plt.xticks(rotation=45)

plt.grid(True)
plt.tight_layout()
plt.show()
